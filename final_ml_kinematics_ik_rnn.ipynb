# %%
# Numerical libraries
import numpy as np
import random as rnd

# Machine learning and data preprocessing libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Plotting library
from keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

import os, sys, datetime
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# PCC model
from kinematics_functions import T_beModule
# from point_clouds import generate_random_points
# from add_error_to_kin import add_error_to_kin
# from ISTlogo_traj import ISTlogo_traj

# read data from Polaris dataset
from data_functions import parse_dataset, polaris2base

# import tensorflow.compat.v1 as tf
# tf.enable_eager_execution(tf.ConfigProto(log_device_placement=False)) 


# config = tf.ConfigProto(device_count = {'GPU': 1})

# %%
rnn_flag = False
rnn_flag = True

diff_flag = False
# diff_flag = True

diff_data = 'cable'
diff_data = 'xyz'

neib_flag = False
# neib_flag = True

write_flag = False
write_flag = True

# data_size_range = np.linspace(0.1, 1, 5)
data_size_range = np.linspace(0.125, 1, 8)
# data_size_range = [0.125, 0.50, 1]
# data_size_range = [1]
test_split = 0.15

# n_range = range(65, 80 + 1, 5)
# h_range = range(1, 4 + 1)

n_range = range(30, 70 + 1, 20)
h_range = range(1, 4 + 1)

MAX_EPOCH = 6000
# MAX_EPOCH = 500
PATIENCE = 300
# PATIENCE = -1
BATCH_SIZE = 128
ACTIVATION_FUN = 'selu'
ACTIVATION_FUN = 'tanh'
ACTIVATION_FUN = 'sigmoid'
ACTIVATION_FUN = 'elu'
ACTIVATION_FUN = 'relu'

# %%
if neib_flag:
    # random w/ neighbors
    datasets = [
        "./data/dataset_1051_rand3N_2024-02-07T114202.txt", # ~500
        "./data/dataset_1051_rand3N_2024-02-07T124945.txt",
        "./data/dataset_1049_rand3N_2024-02-07T144446.txt",
        "./data/dataset_1047_rand3N_2024-02-07T155230.txt", # ~900
        "./data/dataset_7687_rand3N_2024-02-09T113646.txt", # also aprox 1100
        "./data/dataset_1047_rand3N_2024-02-09T130942.txt",
        "./data/dataset_841_rand3N_2024-02-09T164215.txt",
        "./data/dataset_1201_2023-12-19T155359.txt", # for testing, random
        ]

else:
    # random datasets
    datasets = [
        "./data/dataset_1200_2023-12-13T161233.txt",
        "./data/dataset_1200_2023-12-15T145833.txt", # many outliers
        "./data/dataset_1201_2023-12-19T155359.txt",
        "./data/dataset_1100_2024-02-07T165437.txt", # without extreme outlier
        "./data/dataset_1101_2024-02-09T103741.txt",
        "./data/dataset_1101_2024-02-09T141149.txt", # ~700
        ]

jtheta2len = lambda p: (p - 4488.62157) / -26.03760

datasets_result = []

for filename in datasets:
    traj, ref_T, pos = parse_dataset(filename)
    traj_, pos_base, est_pos_base = polaris2base(traj, ref_T, pos)
    datasets_result.append({"traj": traj, "traj_": traj_, "pos_base": pos_base, "est_pos_base": est_pos_base})

x, y = [], []
x_test, y_test = [], []

rnd.seed(420)
inputs = []
outputs = []

num_time_steps = 3
min_max_scaler = MinMaxScaler()
x = [min_max_scaler.fit_transform(seq) for seq in x]

test_idx = rnd.randint(0, len(datasets_result))
# test_idx = np.random.randint(0,len(datasets_result), seed)
x_test = datasets_result[test_idx]["pos_base"]
test_inputs = [tuple(x_test[i:i+num_time_steps,:]) for i in range(1, len(x_test) - num_time_steps + 1)]
y_test = datasets_result[test_idx]["traj_"]
test_outputs = [y_test[i+num_time_steps-1,:] for i in range(1, len(y_test) - num_time_steps + 1)]
datasets_result.pop(test_idx)
x = [dataset.get("pos_base", []) for dataset in datasets_result]
y = [dataset.get("traj_", []) for dataset in datasets_result]


for j in range(len(x)):
    inputs += [tuple(x[j][i:i+num_time_steps,:]) for i in range(1, len(x[j]) - num_time_steps + 1)]
    outputs += [y[j][i+num_time_steps-1,:] for i in range(1, len(x[j]) - num_time_steps + 1)]
    # for i in range(1, len(x[j]) - 1):
    #     inputs.append(tuple(x[j][i:i+2,:]))  # Extract positions for two consecutive time steps
    #     outputs.append(y[j][i+1,:])  # Joint angles at the second time step
        # segments.append((input_pair, output_joint_angles))

inputs = np.array(inputs)
outputs = np.array(outputs)
test_inputs = np.array(test_inputs)
test_outputs = np.array(test_outputs)
print(inputs.shape)
print(outputs.shape)
print(test_inputs.shape)
print(test_outputs.shape)

# x_test = min_max_scaler.fit_transform(x_test) # pos

# print(x_test.shape, y_test.shape)
# Out:
# (5319, 3, 3)
# (5319, 3)
# (1197, 3, 3)
# (1197, 3)

# %%
dt = datetime.datetime.now(datetime.timezone.utc).isoformat().split('.')[0].replace(':', '')

if write_flag:
    results_folder = "./results/final_datasets_rnn"
    if not os.path.exists(results_folder): os.makedirs(results_folder)
    if diff_flag:
        if neib_flag: result_file = open(f'{results_folder}/results_diff_rand3N_{dt}.txt', 'w')
        else: result_file = open(f'{results_folder}/results_diff_rand_{dt}.txt', 'w')
    else: 
        if neib_flag: result_file = open(f'{results_folder}/results_rand3N_{dt}.txt', 'w')
        else: result_file = open(f'{results_folder}/results_rand_{dt}.txt', 'w')
    result_file.write(f'Train Set Size: {len(x)}\n')
    result_file.write(f'Test Set Size: {len(x_test)}\n')
    result_file.write(f'NN Params: Max Epochs - {MAX_EPOCH}; Activation Function - \'{ACTIVATION_FUN}\'; Stopping Criteria Patience - {PATIENCE}; Train Data Shape- {inputs.shape}\n')
    # final_datasets2
    # result_file.write(f'\nArchitechture;pct of train dataset;Epochs;Last Val Loss;MRE [%];MaxRE [%];MAE [mm];MaxAE [mm];MRE (Mean Length) [%];MaxRE (Mean Length) [%];MRE (Full-Scale) [%];MaxRE (Full-Scale) [%]')
    # final_datasets3
    result_file.write(f'\nArchitechture;pct of train dataset;Epochs;Last Val Loss;MRE [%];MaxRE [%];MAE [mm];MaxAE [mm];StdAE [mm];Mean Length;Full-Scale')
    result_file.flush()

# %%
# %reload_ext autoreload
# %autoreload 2

from nn_builder import DNNModelBuilder
from nn_builder import mlp_1, rnn, SimpleRNN

if write_flag:
    models_folder = f"{results_folder}/models_{dt}"
    if not os.path.exists(models_folder): os.makedirs(models_folder)

# max_len = max([len(seq) for seq in x] + [len(x_test)])
for data_size in data_size_range:
    if data_size != 1:
        # x_train, _, y_train, _ = train_test_split(x, y, test_size=1-data_size, random_state=93216)
        x_split = int(len(inputs) * data_size)
        y_split = int(len(outputs) * data_size)
        assert(x_split == y_split)
        x_train = inputs[:x_split]
        y_train = outputs[:y_split]
    else: x_train, y_train = inputs, outputs
        
    # xyz_diff = min_max_scaler.fit_transform(np.array(xyz_diff))
    # x_train = min_max_scaler.fit_transform(x_train) # pos

    # ## Model Design & Selection
    models = []
    for h in h_range:
        if rnn_flag and h > 1: models =  [(rnn, [[(n, True)]*(h-2) + [(n, False)]*2], {}) for n in n_range] # eg
        elif rnn_flag: models =  [(rnn, [[(n, False)]*h], {}) for n in n_range] # eg
        # if rnn_flag: models =  [(SimpleRNN, [], {}) for n in n_range] # eg
        else: models =  [(mlp_1, [[n]*h], {'activation': ACTIVATION_FUN}) for n in n_range] # eg

    # Using the model builder
        builder = DNNModelBuilder(x_train, models)

        # continue
        # print(f"Last model in step: {models[-1][1]}")
        # print(builder.models[-1].summary())

        # print(x_train.shape)
        # if rnn_flag:
        #     # for fold in range(len(x_train)):
        #     #     x_val = x_train[fold:fold+1]
        #     #     y_val = y_train[fold:fold+1]
                
        #     #     # Use all other sequences for training
        #     #     x_fold = np.concatenate([x_train[:fold], x_train[fold+1:]], axis=0)
        #     #     y_fold = np.concatenate([y_train[:fold], y_train[fold+1:]], axis=0)
        #     #     builder.train(x_fold, y_fold, epochs=MAX_EPOCH, batch_size=BATCH_SIZE, patience=PATIENCE, validation_data=(x_val, y_val))
            
        #     # x_train = x_train.reshape(1, sum([len(seq) for seq in x_train]), x_train.shape[2])
        #     # y_train = y_train.reshape(1, sum([len(seq) for seq in y_train]), y_train.shape[2])
        #     # builder.train(x_train, y_train, epochs=MAX_EPOCH, batch_size=BATCH_SIZE, patience=PATIENCE, validation_split=0)

        #     builder.train(x_train, y_train, epochs=MAX_EPOCH, batch_size=BATCH_SIZE, patience=PATIENCE)
        # else:
        builder.train(x_train, y_train, epochs=MAX_EPOCH, batch_size=BATCH_SIZE, validation_split=test_split/(1 - test_split), patience=PATIENCE)
        # for i, model in enumerate(builder.architectures):
        #     print(f"Model {i+1}: {str(model[0]).split(' ')[1]}, {model[1][0]}")
        builder.compare_models(stack=False)
        # losses = builder.evaluate(x_test, y_test)
        # builder.save_models()

        pred = builder.predict(test_inputs)

        # print("Mean Lengths:", np.mean(y_test))
        y_test = test_outputs
        for i, p in enumerate(pred):
            # plot_positions_comparison(np.array(y_test), np.array(p))
            pred_abs_norm_err = np.abs(np.linalg.norm(p - y_test, axis=1))
            pred_rel_mean_err = pred_abs_norm_err / np.mean(y_test) * 100
            pred_rel_norm_err = np.abs(np.linalg.norm(p - y_test, axis=1)) / np.abs(np.linalg.norm(y_test, axis=1)) * 100
            pred_rel_scale_err = pred_abs_norm_err / (np.max(y_test[:,0]) - np.min(y_test[:,0])) * 100
            print(f"\nArchitechture: {str(builder.architectures[i][0]).split(' ')[1]}, {builder.architectures[i][1][0]}")
            print(f"% of data: {data_size * 100:.2f}%")
            print(f"Mean Relative Error: {np.mean(pred_rel_norm_err):.3f}%")
            print(f"Max Relative Error: {max(pred_rel_norm_err):.3f}%")
            print(f"Mean Absolute Error: {np.mean(pred_abs_norm_err):.3f} mm")
            print(f"Max Absolute Error: {max(pred_abs_norm_err):.3f} mm")
            print(f"Mean Relative Error (Mean Length): {np.mean(pred_rel_mean_err):.3f} %")
            print(f"Max Relative Error (Mean Length): {max(pred_rel_mean_err):.3f} %")
            print(f"Mean Relative Error (Full-Scale): {np.mean(pred_rel_scale_err):.3f}%")
            print(f"Max Relative Error (Full-Scale): {max(pred_rel_scale_err):.3f}%")

            if write_flag:
                result_file.write(f"\n{str(builder.architectures[i][0]).split(' ')[1]}, {builder.architectures[i][1][0]}; ")
                result_file.write(f"{data_size*100:.2f}; ")
                if builder.early_stopping == None or builder.early_stopping.stopped_epoch == None or builder.early_stopping.stopped_epoch == 0:
                    result_file.write(f"{MAX_EPOCH}; ")
                else: result_file.write(f"{len(builder.histories[i].history['val_loss'])}; ")
                result_file.write(f"{builder.histories[i].history['val_loss'][-1]:3f}; ")
                result_file.write(f"{np.mean(pred_rel_norm_err):.3f}; ")
                result_file.write(f"{max(pred_rel_norm_err):.3f}; ")
                result_file.write(f"{np.mean(pred_abs_norm_err):.3f}; ")
                result_file.write(f"{max(pred_abs_norm_err):.3f}; ")
                
                result_file.write(f"{np.std(pred_abs_norm_err):.3f}; ")
                result_file.write(f"{np.mean(y_test):3f}; ")
                result_file.write(f"{np.max(y_test[:,0]) - np.min(y_test[:,0]):3f}")
                
                # result_file.write(f"{np.mean(pred_rel_mean_err):.3f}; ")
                # result_file.write(f"{max(pred_rel_mean_err):.3f}; ")
                # result_file.write(f"{np.mean(pred_rel_scale_err):.3f}; ")
                # result_file.write(f"{max(pred_rel_scale_err):.3f}")
                
                result_file.flush()

                builder.save_models(prefix=f"{str(builder.architectures[0][0]).split()[1]}_{int(data_size*100)}pct_{h}L", folder=models_folder)

                if not os.path.exists(f"{models_folder}/imgs/"): os.makedirs(f"{models_folder}/imgs/")
        
            if write_flag and data_size in [0.25, 0.5, 0.75, 1]: plt.savefig(f"{models_folder}/imgs/{str(builder.architectures[0][0]).split()[1]}_{int(data_size*100)}pct_{h}L.png")
            # if write_flag and data_size in [0.25, 0.5, 1]: plt.savefig(f'./results/final_datasets2/imgs/training_{data_size*100:.0f}_{h}L_{dt}.png')

if write_flag: result_file.close()
# Out:
# (664, 3, 3) | (3, 3) | (30, False)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (664, 30)                 1020
#
#  dense (Dense)               (664, 3)                  93
#
# =================================================================
# Total params: 1113 (4.35 KB)
# Trainable params: 1113 (4.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (664, 3, 3) | (3, 3) | (50, False)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (664, 50)                 2700
#
#  dense_1 (Dense)             (664, 3)                  153
#
# =================================================================
# Total params: 2853 (11.14 KB)
# Trainable params: 2853 (11.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (664, 3, 3) | (3, 3) | (70, False)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (664, 70)                 5180
#
#  dense_2 (Dense)             (664, 3)                  213
#
# =================================================================
# Total params: 5393 (21.07 KB)
# Trainable params: 5393 (21.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Training model 2/3
# Training model 3/3
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, False)]
# % of data: 12.50%
# Mean Relative Error: 11.920%
# Max Relative Error: 63.292%
# Mean Absolute Error: 23.804 mm
# Max Absolute Error: 114.713 mm
# Mean Relative Error (Mean Length): 20.721 %
# Max Relative Error (Mean Length): 99.859 %
# Mean Relative Error (Full-Scale): 41.402%
# Max Relative Error (Full-Scale): 199.523%
#
# Architechture: rnn, [(50, False)]
# % of data: 12.50%
# Mean Relative Error: 17.028%
# Max Relative Error: 86.575%
# Mean Absolute Error: 34.064 mm
# Max Absolute Error: 191.651 mm
# Mean Relative Error (Mean Length): 29.653 %
# Max Relative Error (Mean Length): 166.835 %
# Mean Relative Error (Full-Scale): 59.248%
# Max Relative Error (Full-Scale): 333.342%
#
# Architechture: rnn, [(70, False)]
# % of data: 12.50%
# Mean Relative Error: 13.681%
# Max Relative Error: 74.682%
# Mean Absolute Error: 27.300 mm
# Max Absolute Error: 161.329 mm
# Mean Relative Error (Mean Length): 23.765 %
# Max Relative Error (Mean Length): 140.439 %
# Mean Relative Error (Full-Scale): 47.483%
# Max Relative Error (Full-Scale): 280.603%
# (664, 3, 3) | (3, 3) | (30, False) (30, False)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (664, 30)                 1020
#
#  dense_3 (Dense)             (664, 30)                 930
#
#  dense_4 (Dense)             (664, 3)                  93
#
# =================================================================
# Total params: 2043 (7.98 KB)
# Trainable params: 2043 (7.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (664, 3, 3) | (3, 3) | (50, False) (50, False)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_4 (SimpleRNN)    (664, 50)                 2700
#
#  dense_5 (Dense)             (664, 50)                 2550
#
#  dense_6 (Dense)             (664, 3)                  153
#
# =================================================================
# Total params: 5403 (21.11 KB)
# Trainable params: 5403 (21.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (664, 3, 3) | (3, 3) | (70, False) (70, False)
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_5 (SimpleRNN)    (664, 70)                 5180
#
#  dense_7 (Dense)             (664, 70)                 4970
#
#  dense_8 (Dense)             (664, 3)                  213
#
# =================================================================
# Total params: 10363 (40.48 KB)
# Trainable params: 10363 (40.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Training model 2/3
# Training model 3/3
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, False), (30, False)]
# % of data: 12.50%
# Mean Relative Error: 16.712%
# Max Relative Error: 104.739%
# Mean Absolute Error: 33.438 mm
# Max Absolute Error: 201.564 mm
# Mean Relative Error (Mean Length): 29.108 %
# Max Relative Error (Mean Length): 175.464 %
# Mean Relative Error (Full-Scale): 58.159%
# Max Relative Error (Full-Scale): 350.584%
#
# Architechture: rnn, [(50, False), (50, False)]
# % of data: 12.50%
# Mean Relative Error: 12.293%
# Max Relative Error: 82.041%
# Mean Absolute Error: 24.550 mm
# Max Absolute Error: 161.854 mm
# Mean Relative Error (Mean Length): 21.371 %
# Max Relative Error (Mean Length): 140.896 %
# Mean Relative Error (Full-Scale): 42.700%
# Max Relative Error (Full-Scale): 281.515%
#
# Architechture: rnn, [(70, False), (70, False)]
# % of data: 12.50%
# Mean Relative Error: 8.861%
# Max Relative Error: 38.182%
# Mean Absolute Error: 17.654 mm
# Max Absolute Error: 75.045 mm
# Mean Relative Error (Mean Length): 15.368 %
# Max Relative Error (Mean Length): 65.328 %
# Mean Relative Error (Full-Scale): 30.707%
# Max Relative Error (Full-Scale): 130.527%
# (664, 3, 3) | (3, 3) | (30, True) (30, False) (30, False)
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_6 (SimpleRNN)    (664, 3, 30)              1020
#
#  simple_rnn_7 (SimpleRNN)    (664, 30)                 1830
#
#  dense_9 (Dense)             (664, 30)                 930
#
#  dense_10 (Dense)            (664, 3)                  93
#
# =================================================================
# Total params: 3873 (15.13 KB)
# Trainable params: 3873 (15.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (664, 3, 3) | (3, 3) | (50, True) (50, False) (50, False)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_8 (SimpleRNN)    (664, 3, 50)              2700
#
#  simple_rnn_9 (SimpleRNN)    (664, 50)                 5050
#
#  dense_11 (Dense)            (664, 50)                 2550
#
#  dense_12 (Dense)            (664, 3)                  153
#
# =================================================================
# Total params: 10453 (40.83 KB)
# Trainable params: 10453 (40.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (664, 3, 3) | (3, 3) | (70, True) (70, False) (70, False)
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_10 (SimpleRNN)   (664, 3, 70)              5180
#
#  simple_rnn_11 (SimpleRNN)   (664, 70)                 9870
#
#  dense_13 (Dense)            (664, 70)                 4970
#
#  dense_14 (Dense)            (664, 3)                  213
#
# =================================================================
# Total params: 20233 (79.04 KB)
# Trainable params: 20233 (79.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Training model 2/3
# Training model 3/3
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, True), (30, False), (30, False)]
# % of data: 12.50%
# Mean Relative Error: 13.288%
# Max Relative Error: 75.244%
# Mean Absolute Error: 26.526 mm
# Max Absolute Error: 154.219 mm
# Mean Relative Error (Mean Length): 23.092 %
# Max Relative Error (Mean Length): 134.249 %
# Mean Relative Error (Full-Scale): 46.138%
# Max Relative Error (Full-Scale): 268.235%
#
# Architechture: rnn, [(50, True), (50, False), (50, False)]
# % of data: 12.50%
# Mean Relative Error: 9.834%
# Max Relative Error: 40.221%
# Mean Absolute Error: 19.587 mm
# Max Absolute Error: 82.743 mm
# Mean Relative Error (Mean Length): 17.050 %
# Max Relative Error (Mean Length): 72.028 %
# Mean Relative Error (Full-Scale): 34.067%
# Max Relative Error (Full-Scale): 143.916%
#
# Architechture: rnn, [(70, True), (70, False), (70, False)]
# % of data: 12.50%
# Mean Relative Error: 8.849%
# Max Relative Error: 32.702%
# Mean Absolute Error: 17.635 mm
# Max Absolute Error: 62.521 mm
# Mean Relative Error (Mean Length): 15.351 %
# Max Relative Error (Mean Length): 54.425 %
# Mean Relative Error (Full-Scale): 30.673%
# Max Relative Error (Full-Scale): 108.743%
# (664, 3, 3) | (3, 3) | (30, True) (30, True) (30, False) (30, False)
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_12 (SimpleRNN)   (664, 3, 30)              1020
#
#  simple_rnn_13 (SimpleRNN)   (664, 3, 30)              1830
#
#  simple_rnn_14 (SimpleRNN)   (664, 30)                 1830
#
#  dense_15 (Dense)            (664, 30)                 930
#
#  dense_16 (Dense)            (664, 3)                  93
#
# =================================================================
# Total params: 5703 (22.28 KB)
# Trainable params: 5703 (22.28 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (664, 3, 3) | (3, 3) | (50, True) (50, True) (50, False) (50, False)
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_15 (SimpleRNN)   (664, 3, 50)              2700
#
#  simple_rnn_16 (SimpleRNN)   (664, 3, 50)              5050
#
#  simple_rnn_17 (SimpleRNN)   (664, 50)                 5050
#
#  dense_17 (Dense)            (664, 50)                 2550
#
#  dense_18 (Dense)            (664, 3)                  153
#
# =================================================================
# Total params: 15503 (60.56 KB)
# Trainable params: 15503 (60.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (664, 3, 3) | (3, 3) | (70, True) (70, True) (70, False) (70, False)
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_18 (SimpleRNN)   (664, 3, 70)              5180
#
#  simple_rnn_19 (SimpleRNN)   (664, 3, 70)              9870
#
#  simple_rnn_20 (SimpleRNN)   (664, 70)                 9870
#
#  dense_19 (Dense)            (664, 70)                 4970
#
#  dense_20 (Dense)            (664, 3)                  213
#
# =================================================================
# Total params: 30103 (117.59 KB)
# Trainable params: 30103 (117.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Training model 2/3
# Training model 3/3
# 38/38 [==============================] - 1s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
#
# Architechture: rnn, [(30, True), (30, True), (30, False), (30, False)]
# % of data: 12.50%
# Mean Relative Error: 11.217%
# Max Relative Error: 52.739%
# Mean Absolute Error: 22.367 mm
# Max Absolute Error: 105.597 mm
# Mean Relative Error (Mean Length): 19.471 %
# Max Relative Error (Mean Length): 91.923 %
# Mean Relative Error (Full-Scale): 38.904%
# Max Relative Error (Full-Scale): 183.666%
#
# Architechture: rnn, [(50, True), (50, True), (50, False), (50, False)]
# % of data: 12.50%
# Mean Relative Error: 9.206%
# Max Relative Error: 31.870%
# Mean Absolute Error: 18.377 mm
# Max Absolute Error: 56.178 mm
# Mean Relative Error (Mean Length): 15.997 %
# Max Relative Error (Mean Length): 48.903 %
# Mean Relative Error (Full-Scale): 31.964%
# Max Relative Error (Full-Scale): 97.711%
#
# Architechture: rnn, [(70, True), (70, True), (70, False), (70, False)]
# % of data: 12.50%
# Mean Relative Error: 7.699%
# Max Relative Error: 26.144%
# Mean Absolute Error: 15.428 mm
# Max Absolute Error: 53.938 mm
# Mean Relative Error (Mean Length): 13.430 %
# Max Relative Error (Mean Length): 46.954 %
# Mean Relative Error (Full-Scale): 26.834%
# Max Relative Error (Full-Scale): 93.816%
# (1329, 3, 3) | (3, 3) | (30, False)
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_21 (SimpleRNN)   (1329, 30)                1020
#
#  dense_21 (Dense)            (1329, 3)                 93
#
# =================================================================
# Total params: 1113 (4.35 KB)
# Trainable params: 1113 (4.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1329, 3, 3) | (3, 3) | (50, False)
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_22 (SimpleRNN)   (1329, 50)                2700
#
#  dense_22 (Dense)            (1329, 3)                 153
#
# =================================================================
# Total params: 2853 (11.14 KB)
# Trainable params: 2853 (11.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1329, 3, 3) | (3, 3) | (70, False)
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_23 (SimpleRNN)   (1329, 70)                5180
#
#  dense_23 (Dense)            (1329, 3)                 213
#
# =================================================================
# Total params: 5393 (21.07 KB)
# Trainable params: 5393 (21.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 793, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 914, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 646, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, False)]
# % of data: 25.00%
# Mean Relative Error: 3.223%
# Max Relative Error: 15.353%
# Mean Absolute Error: 6.439 mm
# Max Absolute Error: 31.568 mm
# Mean Relative Error (Mean Length): 5.605 %
# Max Relative Error (Mean Length): 27.480 %
# Mean Relative Error (Full-Scale): 11.199%
# Max Relative Error (Full-Scale): 54.907%
#
# Architechture: rnn, [(50, False)]
# % of data: 25.00%
# Mean Relative Error: 3.625%
# Max Relative Error: 14.972%
# Mean Absolute Error: 7.228 mm
# Max Absolute Error: 26.711 mm
# Mean Relative Error (Mean Length): 6.292 %
# Max Relative Error (Mean Length): 23.252 %
# Mean Relative Error (Full-Scale): 12.572%
# Max Relative Error (Full-Scale): 46.459%
#
# Architechture: rnn, [(70, False)]
# % of data: 25.00%
# Mean Relative Error: 3.558%
# Max Relative Error: 15.008%
# Mean Absolute Error: 7.120 mm
# Max Absolute Error: 31.488 mm
# Mean Relative Error (Mean Length): 6.198 %
# Max Relative Error (Mean Length): 27.411 %
# Mean Relative Error (Full-Scale): 12.384%
# Max Relative Error (Full-Scale): 54.767%
# (1329, 3, 3) | (3, 3) | (30, False) (30, False)
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_24 (SimpleRNN)   (1329, 30)                1020
#
#  dense_24 (Dense)            (1329, 30)                930
#
#  dense_25 (Dense)            (1329, 3)                 93
#
# =================================================================
# Total params: 2043 (7.98 KB)
# Trainable params: 2043 (7.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1329, 3, 3) | (3, 3) | (50, False) (50, False)
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_25 (SimpleRNN)   (1329, 50)                2700
#
#  dense_26 (Dense)            (1329, 50)                2550
#
#  dense_27 (Dense)            (1329, 3)                 153
#
# =================================================================
# Total params: 5403 (21.11 KB)
# Trainable params: 5403 (21.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1329, 3, 3) | (3, 3) | (70, False) (70, False)
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_26 (SimpleRNN)   (1329, 70)                5180
#
#  dense_28 (Dense)            (1329, 70)                4970
#
#  dense_29 (Dense)            (1329, 3)                 213
#
# =================================================================
# Total params: 10363 (40.48 KB)
# Trainable params: 10363 (40.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 621, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 461, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 410, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, False), (30, False)]
# % of data: 25.00%
# Mean Relative Error: 3.022%
# Max Relative Error: 25.419%
# Mean Absolute Error: 6.045 mm
# Max Absolute Error: 51.590 mm
# Mean Relative Error (Mean Length): 5.262 %
# Max Relative Error (Mean Length): 44.910 %
# Mean Relative Error (Full-Scale): 10.515%
# Max Relative Error (Full-Scale): 89.731%
#
# Architechture: rnn, [(50, False), (50, False)]
# % of data: 25.00%
# Mean Relative Error: 3.018%
# Max Relative Error: 11.886%
# Mean Absolute Error: 6.013 mm
# Max Absolute Error: 26.987 mm
# Mean Relative Error (Mean Length): 5.234 %
# Max Relative Error (Mean Length): 23.492 %
# Mean Relative Error (Full-Scale): 10.459%
# Max Relative Error (Full-Scale): 46.939%
#
# Architechture: rnn, [(70, False), (70, False)]
# % of data: 25.00%
# Mean Relative Error: 2.754%
# Max Relative Error: 9.661%
# Mean Absolute Error: 5.506 mm
# Max Absolute Error: 20.029 mm
# Mean Relative Error (Mean Length): 4.793 %
# Max Relative Error (Mean Length): 17.435 %
# Mean Relative Error (Full-Scale): 9.577%
# Max Relative Error (Full-Scale): 34.836%
# (1329, 3, 3) | (3, 3) | (30, True) (30, False) (30, False)
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_27 (SimpleRNN)   (1329, 3, 30)             1020
#
#  simple_rnn_28 (SimpleRNN)   (1329, 30)                1830
#
#  dense_30 (Dense)            (1329, 30)                930
#
#  dense_31 (Dense)            (1329, 3)                 93
#
# =================================================================
# Total params: 3873 (15.13 KB)
# Trainable params: 3873 (15.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1329, 3, 3) | (3, 3) | (50, True) (50, False) (50, False)
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_29 (SimpleRNN)   (1329, 3, 50)             2700
#
#  simple_rnn_30 (SimpleRNN)   (1329, 50)                5050
#
#  dense_32 (Dense)            (1329, 50)                2550
#
#  dense_33 (Dense)            (1329, 3)                 153
#
# =================================================================
# Total params: 10453 (40.83 KB)
# Trainable params: 10453 (40.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1329, 3, 3) | (3, 3) | (70, True) (70, False) (70, False)
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_31 (SimpleRNN)   (1329, 3, 70)             5180
#
#  simple_rnn_32 (SimpleRNN)   (1329, 70)                9870
#
#  dense_34 (Dense)            (1329, 70)                4970
#
#  dense_35 (Dense)            (1329, 3)                 213
#
# =================================================================
# Total params: 20233 (79.04 KB)
# Trainable params: 20233 (79.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 535, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 477, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 388, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
#
# Architechture: rnn, [(30, True), (30, False), (30, False)]
# % of data: 25.00%
# Mean Relative Error: 3.643%
# Max Relative Error: 24.361%
# Mean Absolute Error: 7.287 mm
# Max Absolute Error: 52.625 mm
# Mean Relative Error (Mean Length): 6.344 %
# Max Relative Error (Mean Length): 45.811 %
# Mean Relative Error (Full-Scale): 12.675%
# Max Relative Error (Full-Scale): 91.532%
#
# Architechture: rnn, [(50, True), (50, False), (50, False)]
# % of data: 25.00%
# Mean Relative Error: 3.443%
# Max Relative Error: 18.511%
# Mean Absolute Error: 6.859 mm
# Max Absolute Error: 36.519 mm
# Mean Relative Error (Mean Length): 5.971 %
# Max Relative Error (Mean Length): 31.790 %
# Mean Relative Error (Full-Scale): 11.931%
# Max Relative Error (Full-Scale): 63.518%
#
# Architechture: rnn, [(70, True), (70, False), (70, False)]
# % of data: 25.00%
# Mean Relative Error: 3.253%
# Max Relative Error: 12.562%
# Mean Absolute Error: 6.501 mm
# Max Absolute Error: 23.602 mm
# Mean Relative Error (Mean Length): 5.659 %
# Max Relative Error (Mean Length): 20.546 %
# Mean Relative Error (Full-Scale): 11.307%
# Max Relative Error (Full-Scale): 41.051%
# (1329, 3, 3) | (3, 3) | (30, True) (30, True) (30, False) (30, False)
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_33 (SimpleRNN)   (1329, 3, 30)             1020
#
#  simple_rnn_34 (SimpleRNN)   (1329, 3, 30)             1830
#
#  simple_rnn_35 (SimpleRNN)   (1329, 30)                1830
#
#  dense_36 (Dense)            (1329, 30)                930
#
#  dense_37 (Dense)            (1329, 3)                 93
#
# =================================================================
# Total params: 5703 (22.28 KB)
# Trainable params: 5703 (22.28 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1329, 3, 3) | (3, 3) | (50, True) (50, True) (50, False) (50, False)
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_36 (SimpleRNN)   (1329, 3, 50)             2700
#
#  simple_rnn_37 (SimpleRNN)   (1329, 3, 50)             5050
#
#  simple_rnn_38 (SimpleRNN)   (1329, 50)                5050
#
#  dense_38 (Dense)            (1329, 50)                2550
#
#  dense_39 (Dense)            (1329, 3)                 153
#
# =================================================================
# Total params: 15503 (60.56 KB)
# Trainable params: 15503 (60.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1329, 3, 3) | (3, 3) | (70, True) (70, True) (70, False) (70, False)
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_39 (SimpleRNN)   (1329, 3, 70)             5180
#
#  simple_rnn_40 (SimpleRNN)   (1329, 3, 70)             9870
#
#  simple_rnn_41 (SimpleRNN)   (1329, 70)                9870
#
#  dense_40 (Dense)            (1329, 70)                4970
#
#  dense_41 (Dense)            (1329, 3)                 213
#
# =================================================================
# Total params: 30103 (117.59 KB)
# Trainable params: 30103 (117.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 562, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 438, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 398, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
#
# Architechture: rnn, [(30, True), (30, True), (30, False), (30, False)]
# % of data: 25.00%
# Mean Relative Error: 3.667%
# Max Relative Error: 17.713%
# Mean Absolute Error: 7.344 mm
# Max Absolute Error: 38.127 mm
# Mean Relative Error (Mean Length): 6.393 %
# Max Relative Error (Mean Length): 33.190 %
# Mean Relative Error (Full-Scale): 12.773%
# Max Relative Error (Full-Scale): 66.315%
#
# Architechture: rnn, [(50, True), (50, True), (50, False), (50, False)]
# % of data: 25.00%
# Mean Relative Error: 3.412%
# Max Relative Error: 13.557%
# Mean Absolute Error: 6.839 mm
# Max Absolute Error: 29.652 mm
# Mean Relative Error (Mean Length): 5.954 %
# Max Relative Error (Mean Length): 25.813 %
# Mean Relative Error (Full-Scale): 11.896%
# Max Relative Error (Full-Scale): 51.575%
#
# Architechture: rnn, [(70, True), (70, True), (70, False), (70, False)]
# % of data: 25.00%
# Mean Relative Error: 3.108%
# Max Relative Error: 12.025%
# Mean Absolute Error: 6.234 mm
# Max Absolute Error: 25.686 mm
# Mean Relative Error (Mean Length): 5.427 %
# Max Relative Error (Mean Length): 22.360 %
# Mean Relative Error (Full-Scale): 10.843%
# Max Relative Error (Full-Scale): 44.677%
# (1994, 3, 3) | (3, 3) | (30, False)
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_42 (SimpleRNN)   (1994, 30)                1020
#
#  dense_42 (Dense)            (1994, 3)                 93
#
# =================================================================
# Total params: 1113 (4.35 KB)
# Trainable params: 1113 (4.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1994, 3, 3) | (3, 3) | (50, False)
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_43 (SimpleRNN)   (1994, 50)                2700
#
#  dense_43 (Dense)            (1994, 3)                 153
#
# =================================================================
# Total params: 2853 (11.14 KB)
# Trainable params: 2853 (11.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1994, 3, 3) | (3, 3) | (70, False)
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_44 (SimpleRNN)   (1994, 70)                5180
#
#  dense_44 (Dense)            (1994, 3)                 213
#
# =================================================================
# Total params: 5393 (21.07 KB)
# Trainable params: 5393 (21.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 1056, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 688, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 606, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, False)]
# % of data: 37.50%
# Mean Relative Error: 2.458%
# Max Relative Error: 15.201%
# Mean Absolute Error: 4.923 mm
# Max Absolute Error: 32.617 mm
# Mean Relative Error (Mean Length): 4.285 %
# Max Relative Error (Mean Length): 28.394 %
# Mean Relative Error (Full-Scale): 8.562%
# Max Relative Error (Full-Scale): 56.732%
#
# Architechture: rnn, [(50, False)]
# % of data: 37.50%
# Mean Relative Error: 2.486%
# Max Relative Error: 10.336%
# Mean Absolute Error: 4.966 mm
# Max Absolute Error: 22.005 mm
# Mean Relative Error (Mean Length): 4.323 %
# Max Relative Error (Mean Length): 19.156 %
# Mean Relative Error (Full-Scale): 8.638%
# Max Relative Error (Full-Scale): 38.274%
#
# Architechture: rnn, [(70, False)]
# % of data: 37.50%
# Mean Relative Error: 2.964%
# Max Relative Error: 14.992%
# Mean Absolute Error: 5.941 mm
# Max Absolute Error: 32.411 mm
# Mean Relative Error (Mean Length): 5.172 %
# Max Relative Error (Mean Length): 28.215 %
# Mean Relative Error (Full-Scale): 10.334%
# Max Relative Error (Full-Scale): 56.374%
# (1994, 3, 3) | (3, 3) | (30, False) (30, False)
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_45 (SimpleRNN)   (1994, 30)                1020
#
#  dense_45 (Dense)            (1994, 30)                930
#
#  dense_46 (Dense)            (1994, 3)                 93
#
# =================================================================
# Total params: 2043 (7.98 KB)
# Trainable params: 2043 (7.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1994, 3, 3) | (3, 3) | (50, False) (50, False)
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_46 (SimpleRNN)   (1994, 50)                2700
#
#  dense_47 (Dense)            (1994, 50)                2550
#
#  dense_48 (Dense)            (1994, 3)                 153
#
# =================================================================
# Total params: 5403 (21.11 KB)
# Trainable params: 5403 (21.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1994, 3, 3) | (3, 3) | (70, False) (70, False)
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_47 (SimpleRNN)   (1994, 70)                5180
#
#  dense_49 (Dense)            (1994, 70)                4970
#
#  dense_50 (Dense)            (1994, 3)                 213
#
# =================================================================
# Total params: 10363 (40.48 KB)
# Trainable params: 10363 (40.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 685, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 492, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 424, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, False), (30, False)]
# % of data: 37.50%
# Mean Relative Error: 2.125%
# Max Relative Error: 14.359%
# Mean Absolute Error: 4.247 mm
# Max Absolute Error: 27.711 mm
# Mean Relative Error (Mean Length): 3.697 %
# Max Relative Error (Mean Length): 24.123 %
# Mean Relative Error (Full-Scale): 7.387%
# Max Relative Error (Full-Scale): 48.198%
#
# Architechture: rnn, [(50, False), (50, False)]
# % of data: 37.50%
# Mean Relative Error: 2.296%
# Max Relative Error: 9.454%
# Mean Absolute Error: 4.590 mm
# Max Absolute Error: 19.819 mm
# Mean Relative Error (Mean Length): 3.995 %
# Max Relative Error (Mean Length): 17.253 %
# Mean Relative Error (Full-Scale): 7.983%
# Max Relative Error (Full-Scale): 34.472%
#
# Architechture: rnn, [(70, False), (70, False)]
# % of data: 37.50%
# Mean Relative Error: 2.201%
# Max Relative Error: 10.479%
# Mean Absolute Error: 4.401 mm
# Max Absolute Error: 17.797 mm
# Mean Relative Error (Mean Length): 3.831 %
# Max Relative Error (Mean Length): 15.492 %
# Mean Relative Error (Full-Scale): 7.654%
# Max Relative Error (Full-Scale): 30.954%
# (1994, 3, 3) | (3, 3) | (30, True) (30, False) (30, False)
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_48 (SimpleRNN)   (1994, 3, 30)             1020
#
#  simple_rnn_49 (SimpleRNN)   (1994, 30)                1830
#
#  dense_51 (Dense)            (1994, 30)                930
#
#  dense_52 (Dense)            (1994, 3)                 93
#
# =================================================================
# Total params: 3873 (15.13 KB)
# Trainable params: 3873 (15.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1994, 3, 3) | (3, 3) | (50, True) (50, False) (50, False)
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_50 (SimpleRNN)   (1994, 3, 50)             2700
#
#  simple_rnn_51 (SimpleRNN)   (1994, 50)                5050
#
#  dense_53 (Dense)            (1994, 50)                2550
#
#  dense_54 (Dense)            (1994, 3)                 153
#
# =================================================================
# Total params: 10453 (40.83 KB)
# Trainable params: 10453 (40.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (1994, 3, 3) | (3, 3) | (70, True) (70, False) (70, False)
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_52 (SimpleRNN)   (1994, 3, 70)             5180
#
#  simple_rnn_53 (SimpleRNN)   (1994, 70)                9870
#
#  dense_55 (Dense)            (1994, 70)                4970
#
#  dense_56 (Dense)            (1994, 3)                 213
#
# =================================================================
# Total params: 20233 (79.04 KB)
# Trainable params: 20233 (79.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 484, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 450, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 392, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, True), (30, False), (30, False)]
# % of data: 37.50%
# Mean Relative Error: 2.509%
# Max Relative Error: 11.512%
# Mean Absolute Error: 5.030 mm
# Max Absolute Error: 25.163 mm
# Mean Relative Error (Mean Length): 4.379 %
# Max Relative Error (Mean Length): 21.905 %
# Mean Relative Error (Full-Scale): 8.749%
# Max Relative Error (Full-Scale): 43.767%
#
# Architechture: rnn, [(50, True), (50, False), (50, False)]
# % of data: 37.50%
# Mean Relative Error: 2.614%
# Max Relative Error: 12.547%
# Mean Absolute Error: 5.219 mm
# Max Absolute Error: 25.020 mm
# Mean Relative Error (Mean Length): 4.543 %
# Max Relative Error (Mean Length): 21.781 %
# Mean Relative Error (Full-Scale): 9.077%
# Max Relative Error (Full-Scale): 43.518%
#
# ...
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 685, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 606, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, False)]
# % of data: 100.00%
# Mean Relative Error: 1.962%
# Max Relative Error: 6.166%
# Mean Absolute Error: 3.902 mm
# Max Absolute Error: 12.695 mm
# Mean Relative Error (Mean Length): 3.396 %
# Max Relative Error (Mean Length): 11.051 %
# Mean Relative Error (Full-Scale): 6.786%
# Max Relative Error (Full-Scale): 22.081%
#
# Architechture: rnn, [(50, False)]
# % of data: 100.00%
# Mean Relative Error: 1.491%
# Max Relative Error: 6.691%
# Mean Absolute Error: 2.973 mm
# Max Absolute Error: 14.026 mm
# Mean Relative Error (Mean Length): 2.588 %
# Max Relative Error (Mean Length): 12.210 %
# Mean Relative Error (Full-Scale): 5.170%
# Max Relative Error (Full-Scale): 24.395%
#
# Architechture: rnn, [(70, False)]
# % of data: 100.00%
# Mean Relative Error: 1.572%
# Max Relative Error: 7.527%
# Mean Absolute Error: 3.141 mm
# Max Absolute Error: 14.876 mm
# Mean Relative Error (Mean Length): 2.734 %
# Max Relative Error (Mean Length): 12.950 %
# Mean Relative Error (Full-Scale): 5.463%
# Max Relative Error (Full-Scale): 25.875%
# (5319, 3, 3) | (3, 3) | (30, False) (30, False)
# Model: "sequential_87"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_150 (SimpleRNN)  (5319, 30)                1020
#
#  dense_150 (Dense)           (5319, 30)                930
#
#  dense_151 (Dense)           (5319, 3)                 93
#
# =================================================================
# Total params: 2043 (7.98 KB)
# Trainable params: 2043 (7.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (5319, 3, 3) | (3, 3) | (50, False) (50, False)
# Model: "sequential_88"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_151 (SimpleRNN)  (5319, 50)                2700
#
#  dense_152 (Dense)           (5319, 50)                2550
#
#  dense_153 (Dense)           (5319, 3)                 153
#
# =================================================================
# Total params: 5403 (21.11 KB)
# Trainable params: 5403 (21.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (5319, 3, 3) | (3, 3) | (70, False) (70, False)
# Model: "sequential_89"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_152 (SimpleRNN)  (5319, 70)                5180
#
#  dense_154 (Dense)           (5319, 70)                4970
#
#  dense_155 (Dense)           (5319, 3)                 213
#
# =================================================================
# Total params: 10363 (40.48 KB)
# Trainable params: 10363 (40.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 636, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 567, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 447, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, False), (30, False)]
# % of data: 100.00%
# Mean Relative Error: 1.173%
# Max Relative Error: 4.277%
# Mean Absolute Error: 2.340 mm
# Max Absolute Error: 9.642 mm
# Mean Relative Error (Mean Length): 2.037 %
# Max Relative Error (Mean Length): 8.393 %
# Mean Relative Error (Full-Scale): 4.070%
# Max Relative Error (Full-Scale): 16.770%
#
# Architechture: rnn, [(50, False), (50, False)]
# % of data: 100.00%
# Mean Relative Error: 1.391%
# Max Relative Error: 4.484%
# Mean Absolute Error: 2.769 mm
# Max Absolute Error: 9.523 mm
# Mean Relative Error (Mean Length): 2.410 %
# Max Relative Error (Mean Length): 8.290 %
# Mean Relative Error (Full-Scale): 4.816%
# Max Relative Error (Full-Scale): 16.563%
#
# Architechture: rnn, [(70, False), (70, False)]
# % of data: 100.00%
# Mean Relative Error: 1.437%
# Max Relative Error: 5.396%
# Mean Absolute Error: 2.864 mm
# Max Absolute Error: 10.546 mm
# Mean Relative Error (Mean Length): 2.494 %
# Max Relative Error (Mean Length): 9.181 %
# Mean Relative Error (Full-Scale): 4.982%
# Max Relative Error (Full-Scale): 18.343%
# (5319, 3, 3) | (3, 3) | (30, True) (30, False) (30, False)
# Model: "sequential_90"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_153 (SimpleRNN)  (5319, 3, 30)             1020
#
#  simple_rnn_154 (SimpleRNN)  (5319, 30)                1830
#
#  dense_156 (Dense)           (5319, 30)                930
#
#  dense_157 (Dense)           (5319, 3)                 93
#
# =================================================================
# Total params: 3873 (15.13 KB)
# Trainable params: 3873 (15.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (5319, 3, 3) | (3, 3) | (50, True) (50, False) (50, False)
# Model: "sequential_91"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_155 (SimpleRNN)  (5319, 3, 50)             2700
#
#  simple_rnn_156 (SimpleRNN)  (5319, 50)                5050
#
#  dense_158 (Dense)           (5319, 50)                2550
#
#  dense_159 (Dense)           (5319, 3)                 153
#
# =================================================================
# Total params: 10453 (40.83 KB)
# Trainable params: 10453 (40.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (5319, 3, 3) | (3, 3) | (70, True) (70, False) (70, False)
# Model: "sequential_92"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_157 (SimpleRNN)  (5319, 3, 70)             5180
#
#  simple_rnn_158 (SimpleRNN)  (5319, 70)                9870
#
#  dense_160 (Dense)           (5319, 70)                4970
#
#  dense_161 (Dense)           (5319, 3)                 213
#
# =================================================================
# Total params: 20233 (79.04 KB)
# Trainable params: 20233 (79.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 559, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 463, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 378, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 1ms/step
#
# Architechture: rnn, [(30, True), (30, False), (30, False)]
# % of data: 100.00%
# Mean Relative Error: 1.447%
# Max Relative Error: 5.422%
# Mean Absolute Error: 2.897 mm
# Max Absolute Error: 10.470 mm
# Mean Relative Error (Mean Length): 2.522 %
# Max Relative Error (Mean Length): 9.115 %
# Mean Relative Error (Full-Scale): 5.039%
# Max Relative Error (Full-Scale): 18.211%
#
# Architechture: rnn, [(50, True), (50, False), (50, False)]
# % of data: 100.00%
# Mean Relative Error: 1.431%
# Max Relative Error: 5.276%
# Mean Absolute Error: 2.852 mm
# Max Absolute Error: 11.320 mm
# Mean Relative Error (Mean Length): 2.483 %
# Max Relative Error (Mean Length): 9.854 %
# Mean Relative Error (Full-Scale): 4.961%
# Max Relative Error (Full-Scale): 19.689%
#
# Architechture: rnn, [(70, True), (70, False), (70, False)]
# % of data: 100.00%
# Mean Relative Error: 1.658%
# Max Relative Error: 6.702%
# Mean Absolute Error: 3.307 mm
# Max Absolute Error: 13.377 mm
# Mean Relative Error (Mean Length): 2.879 %
# Max Relative Error (Mean Length): 11.645 %
# Mean Relative Error (Full-Scale): 5.752%
# Max Relative Error (Full-Scale): 23.267%
# (5319, 3, 3) | (3, 3) | (30, True) (30, True) (30, False) (30, False)
# Model: "sequential_93"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_159 (SimpleRNN)  (5319, 3, 30)             1020
#
#  simple_rnn_160 (SimpleRNN)  (5319, 3, 30)             1830
#
#  simple_rnn_161 (SimpleRNN)  (5319, 30)                1830
#
#  dense_162 (Dense)           (5319, 30)                930
#
#  dense_163 (Dense)           (5319, 3)                 93
#
# =================================================================
# Total params: 5703 (22.28 KB)
# Trainable params: 5703 (22.28 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (5319, 3, 3) | (3, 3) | (50, True) (50, True) (50, False) (50, False)
# Model: "sequential_94"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_162 (SimpleRNN)  (5319, 3, 50)             2700
#
#  simple_rnn_163 (SimpleRNN)  (5319, 3, 50)             5050
#
#  simple_rnn_164 (SimpleRNN)  (5319, 50)                5050
#
#  dense_164 (Dense)           (5319, 50)                2550
#
#  dense_165 (Dense)           (5319, 3)                 153
#
# =================================================================
# Total params: 15503 (60.56 KB)
# Trainable params: 15503 (60.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# (5319, 3, 3) | (3, 3) | (70, True) (70, True) (70, False) (70, False)
# Model: "sequential_95"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_165 (SimpleRNN)  (5319, 3, 70)             5180
#
#  simple_rnn_166 (SimpleRNN)  (5319, 3, 70)             9870
#
#  simple_rnn_167 (SimpleRNN)  (5319, 70)                9870
#
#  dense_166 (Dense)           (5319, 70)                4970
#
#  dense_167 (Dense)           (5319, 3)                 213
#
# =================================================================
# Total params: 30103 (117.59 KB)
# Trainable params: 30103 (117.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 677, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 449, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 385, val_loss moving average didn't improve for 300 consecutive epochs.
# 38/38 [==============================] - 0s 1ms/step
# 38/38 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
#
# Architechture: rnn, [(30, True), (30, True), (30, False), (30, False)]
# % of data: 100.00%
# Mean Relative Error: 1.598%
# Max Relative Error: 6.880%
# Mean Absolute Error: 3.188 mm
# Max Absolute Error: 14.485 mm
# Mean Relative Error (Mean Length): 2.776 %
# Max Relative Error (Mean Length): 12.610 %
# Mean Relative Error (Full-Scale): 5.546%
# Max Relative Error (Full-Scale): 25.194%
#
# Architechture: rnn, [(50, True), (50, True), (50, False), (50, False)]
# % of data: 100.00%
# Mean Relative Error: 1.739%
# Max Relative Error: 9.423%
# Mean Absolute Error: 3.470 mm
# Max Absolute Error: 18.320 mm
# Mean Relative Error (Mean Length): 3.021 %
# Max Relative Error (Mean Length): 15.947 %
# Mean Relative Error (Full-Scale): 6.036%
# Max Relative Error (Full-Scale): 31.864%
#
# Architechture: rnn, [(70, True), (70, True), (70, False), (70, False)]
# % of data: 100.00%
# Mean Relative Error: 1.618%
# Max Relative Error: 5.859%
# Mean Absolute Error: 3.233 mm
# Max Absolute Error: 11.523 mm
# Mean Relative Error (Mean Length): 2.814 %
# Max Relative Error (Mean Length): 10.031 %
# Mean Relative Error (Full-Scale): 5.622%
# Max Relative Error (Full-Scale): 20.042%

# %%
# if not os.path.exists(f"{folder}/imgs/"): os.makedirs(f"{folder}/imgs/")
# print(test_outputs.shape)
# builder.predict(x_test)
# plt.savefig(f"{folder}/imgs/{str(builder.architectures[0][0]).split()[1]}_{int(data_size*100)}pct_{h}L.png")

# result_file.flush()

# result_file.close()
