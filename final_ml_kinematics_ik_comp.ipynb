# %%
# Numerical libraries
import numpy as np

# Machine learning and data preprocessing libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Plotting library
import matplotlib.pyplot as plt

import os, sys, datetime
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# PCC model
from kinematics_functions import T_beModule, invKspace_car
# from point_clouds import generate_random_points
# from add_error_to_kin import add_error_to_kin
# from ISTlogo_traj import ISTlogo_traj

# read data from Polaris dataset
from data_functions import parse_dataset, polaris2base

# import tensorflow.compat.v1 as tf
# tf.enable_eager_execution(tf.ConfigProto(log_device_placement=False)) 
from nn_builder import DNNModelBuilder
from nn_builder import mlp_1


# config = tf.ConfigProto(device_count = {'GPU': 1})

# %%
diff_flag = False
diff_flag = True

diff_data = 'cable'
diff_data = 'xyz'

neib_flag = False
# neib_flag = True

write_flag = False
write_flag = True

# data_size_range = np.linspace(0.1, 1, 5)
# data_size_range = np.linspace(0.125, .875, 4)
# data_size_range = np.linspace(0.25, 1, 4)
# data_size_range = np.linspace(0.5, 1, 5)
data_size_range = np.linspace(0.125, 1, 8)
# data_size_range = [1]
test_split = 0.15

# n_range = range(40, 80 + 1, 10)
# n_range = range(35, 85 + 1, 10)
# n_range = range(35, 85 + 1, 5)
# h_range = range(1, 4 + 1)

n_range = range(90, 100 + 1, 5)
h_range = range(2, 3 + 1)

MAX_EPOCH = 7500
# MAX_EPOCH = 500
PATIENCE = 300
# PATIENCE = -1
BATCH_SIZE = 128
ACTIVATION_FUN = 'selu'
ACTIVATION_FUN = 'tanh'
ACTIVATION_FUN = 'sigmoid'
ACTIVATION_FUN = 'elu'
ACTIVATION_FUN = 'relu'

# %%
if neib_flag:
    # random w/ neighbors
    datasets = [
        "./data/dataset_1051_rand3N_2024-02-07T114202.txt", # ~500
        "./data/dataset_1051_rand3N_2024-02-07T124945.txt",
        "./data/dataset_1049_rand3N_2024-02-07T144446.txt",
        "./data/dataset_1047_rand3N_2024-02-07T155230.txt", # ~900
        "./data/dataset_7687_rand3N_2024-02-09T113646.txt", # also aprox 1100
        "./data/dataset_1047_rand3N_2024-02-09T130942.txt",
        "./data/dataset_841_rand3N_2024-02-09T164215.txt",
        "./data/dataset_1201_2023-12-19T155359.txt", # for testing, random
        ]

else:
    # random datasets
    datasets = [
        "./data/dataset_1200_2023-12-13T161233.txt",
        "./data/dataset_1200_2023-12-15T145833.txt", # many outliers
        "./data/dataset_1201_2023-12-19T155359.txt",
        "./data/dataset_1100_2024-02-07T165437.txt", # without extreme outlier
        "./data/dataset_1101_2024-02-09T103741.txt",
        "./data/dataset_1101_2024-02-09T141149.txt", # ~700
        ]

jtheta2len = lambda p: (p - 4488.62157) / -26.03760

datasets_result = []

for filename in datasets:
    traj, ref_T, pos = parse_dataset(filename)
    traj_, pos_base, est_pos_base = polaris2base(traj, ref_T, pos)
    datasets_result.append({"traj": traj, "traj_": traj_, "pos_base": pos_base, "est_pos_base": est_pos_base})

x, y = [], []
x_test, y_test = [], []

if diff_flag and diff_data == 'xyz':
    xyz_diff = np.empty((0, 3))
    xyz_diff_test = np.empty((0, 3))
elif diff_flag and diff_data == 'cable':
    cable_diff = []
    cable_diff_test = []

pcc_err_tol = 20
for i, dataset in enumerate(datasets_result):
    abs_err_norm = np.linalg.norm(dataset.get("pos_base") - dataset.get("est_pos_base"), axis=1)
    # pcc_err_tol = np.mean(abs_err_norm) + np.std(abs_err_norm).astype(float) * 3
    mask = abs_err_norm < pcc_err_tol
    print("mask", i, all(mask))
    if (neib_flag) and i == len(datasets) - 1:
        x_test += [invKspace_car(*p, theta_flag=False) for p in dataset.get("pos_base")[mask]]
        # x_test += list((dataset.get("pos_base")[mask]))
        y_test += list(dataset.get("traj_")[mask])
        if diff_flag and diff_data == 'xyz':
            xyz_diff_temp = np.diff(np.insert([invKspace_car(*p, theta_flag=False) for p in dataset.get("pos_base")[mask]], 0, y[0], axis=0), axis=0)
            # xyz_diff_temp = np.diff(np.insert((dataset.get("pos_base")[mask]), 0, T_beModule(y[0], [], 0, 0)[:3, 3], axis=0), axis=0)
            xyz_diff_test = np.concatenate((xyz_diff_test, xyz_diff_temp / np.linalg.norm(xyz_diff_temp, axis=1, keepdims=True)))
        elif diff_flag and diff_data == 'cable':
            cable_diff_temp = np.diff(np.insert(dataset.get("traj_")[mask], 0, y[0], axis=0))
            cable_diff_test += cable_diff_temp# / np.linalg.norm(cable_diff_temp, axis=1)
    else:
        x += [invKspace_car(*p, theta_flag=False) for p in dataset.get("pos_base")[mask]]
        # x += list((dataset.get("pos_base")[mask]))
        y += list(dataset.get("traj_")[mask])
        # print(len(x))
        if diff_flag and diff_data == 'xyz':
            # xyz_diff_temp = np.diff(np.insert((dataset.get("pos_base")[mask]), 0, T_beModule(y[0], [], 0, 0)[:3, 3], axis=0), axis=0)
            xyz_diff_temp = np.diff(np.insert([invKspace_car(*p, theta_flag=False) for p in dataset.get("pos_base")[mask]], 0, y[0], axis=0), axis=0)
            xyz_diff_temp = np.diff((dataset.get("pos_base")[mask]), axis=0)
            # xyz_diff_temp = np.diff((dataset.get("pos_base")[mask]), axis=0)
            # print(len(xyz_diff_temp))
            # xyz_diff = np.concatenate((xyz_diff, np.zeros((1,3)), xyz_diff_temp), axis=0)
            xyz_diff = np.concatenate((xyz_diff, np.zeros((1,3)), xyz_diff_temp / np.linalg.norm(xyz_diff_temp, axis=1, keepdims=True)), axis=0)
            # print(len(xyz_diff))
        elif diff_flag and diff_data == 'cable':
            cable_diff_temp = np.diff(np.insert(dataset.get("traj_")[mask], 0, y[0], axis=0))
            cable_diff += cable_diff_temp / np.linalg.norm(cable_diff_temp, axis=1)


if diff_flag and diff_data == 'xyz':
    x = np.hstack((x, xyz_diff))
    # x_test = np.hstack((x_test, xyz_diff_test[1:]))
elif diff_flag and diff_data == 'cable':
    x = np.hstack((x, cable_diff[1:]))
    x_test = np.hstack((x_test, cable_diff_test[1:]))
else:
    x, y = np.array(x), np.array(y)
    x_test, y_test = np.array(x_test), np.array(y_test)

if not neib_flag or not diff_flag:
    # x, x_test, y, y_test = train_test_split(x, y, test_size=test_split, shuffle=False) # prev 93216
    x, x_test, y, y_test = train_test_split(x, y, test_size=test_split, random_state=93216) # prev 42
y = np.array(y)
y_test = np.array(y_test)
    
min_max_scaler = MinMaxScaler()
x = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.fit_transform(x_test) # pos

print(x.shape, y.shape)
print(x_test.shape, y_test.shape)
print(x_test[:5], y_test[:5])
# Out:
# mask 0 True
# mask 1 False
# mask 2 True
# mask 3 True
# mask 4 True
# mask 5 False
# (5296, 6) (5296, 3)
# (935, 6) (935, 3)
# [[0.61257475 0.21695088 0.63847063 0.80845459 0.12730477 0.37706989]
#  [0.1769143  0.78957072 0.13304186 0.29925654 0.7912539  0.14256451]
#  [0.15517153 0.59486937 0.14303955 0.5720094  0.99046724 0.43920448]
#  [0.53269047 0.65597199 0.37341423 0.45080005 0.99039593 0.59931867]
#  [0.10974398 0.2044275  0.28102277 0.34924684 0.03928818 0.63835924]] [[124.38249186  99.11134552 125.2658298 ]
#  [ 95.65480574 138.05502696  90.96927405]
#  [ 96.00045972 124.15205587  93.2736339 ]
#  [121.23320006 128.56874558 110.63314476]
#  [ 94.34900183  98.84250353 101.56932935]]

# %%
# min_values = min_max_scaler.data_min_
# max_values = min_max_scaler.data_max_
# np.savez('data_norm_w-diff_comp.npz', min_values=min_values, max_values=max_values)
# min_max_values = np.load('data_norm_w-diff_comp.npz')
# min_values = min_max_values['min_values']
# max_values = min_max_values['max_values']
# norm_data = (data - min_values) / (max_values - min_values)

# %%
dt = datetime.datetime.now(datetime.timezone.utc).isoformat().split('.')[0].replace(':', '')

if write_flag:
    results_folder = "./results/final_datasets_comp"
    # results_folder = "./results/final_datasets3"
    if not os.path.exists(results_folder): os.makedirs(results_folder)
    if diff_flag:
        if neib_flag: result_file = open(f'{results_folder}/results_diff_rand3N_{dt}.txt', 'w')
        else: result_file = open(f'{results_folder}/results_diff_rand_{dt}.txt', 'w')
    else: 
        if neib_flag: result_file = open(f'{results_folder}/results_rand3N_{dt}.txt', 'w')
        else: result_file = open(f'{results_folder}/results_rand_{dt}.txt', 'w')
    result_file.write(f'Train Set Size: {len(x)}\n')
    result_file.write(f'Test Set Size: {len(x_test)}\n')
    result_file.write(f'NN Params: Max Epochs - {MAX_EPOCH}; Activation Function - \'{ACTIVATION_FUN}\'; Stopping Criteria Patience - {PATIENCE}\n')
    # final_datasets2
    # result_file.write(f'\nArchitechture;pct of train dataset;Epochs;Last Val Loss;MRE [%];MaxRE [%];MAE [mm];MaxAE [mm];MRE (Mean Length) [%];MaxRE (Mean Length) [%];MRE (Full-Scale) [%];MaxRE (Full-Scale) [%]')
    # final_datasets3
    result_file.write(f'\nArchitechture;pct of train dataset;Epochs;Last Val Loss;MRE [%];MaxRE [%];MAE [mm];MaxAE [mm];StdAE [mm];Mean Length;Full-Scale')
    result_file.flush()

# %%
if write_flag:
    models_folder = f"{results_folder}/models_{dt}"
    if not os.path.exists(models_folder): os.makedirs(models_folder)
for data_size in data_size_range:
    if data_size != 1:
        # x_train, _, y_train, _ = train_test_split(x, y, test_size=1-data_size, random_state=93216)
        x_split = int(len(x) * data_size)
        y_split = int(len(y) * data_size)
        assert(x_split == y_split)
        x_train = x[:x_split]
        y_train = y[:y_split]
    else: x_train, y_train = x, y
        
    # xyz_diff = min_max_scaler.fit_transform(np.array(xyz_diff))
    # x_train = min_max_scaler.fit_transform(x_train) # pos


    # ## Model Design & Selection
    models = []
    for h in h_range:
        # if rnn_flag: models =  [(rnn, [[(n, False)]*h], {'activation': ACTIVATION_FUN}) for n in n_range] # eg
        models =  [(mlp_1, [[n]*h], {'activation': ACTIVATION_FUN}) for n in n_range] # eg

    # Using the model builder
        builder = DNNModelBuilder(x_train, models)

        # print(f"Last model in step: {models[-1][1]}")
        # print(builder.models[-1].summary())

        # print(x_train.shape)
        builder.train(x_train, y_train, epochs=MAX_EPOCH, batch_size=BATCH_SIZE, validation_split=test_split/(1 - test_split), patience=PATIENCE)
        # for i, model in enumerate(builder.architectures):
        #     print(f"Model {i+1}: {str(model[0]).split(' ')[1]}, {model[1][0]}")
        builder.compare_models(stack=False)
        # losses = builder.evaluate(x_test, y_test)
        # builder.save_models()

        pred = builder.predict(x_test)

        # print("Mean Lengths:", np.mean(y_test))
        for i, p in enumerate(pred):
            # plot_positions_comparison(np.array(y_test), np.array(p))
            pred_abs_norm_err = np.abs(np.linalg.norm(p - y_test, axis=1))
            pred_rel_mean_err = pred_abs_norm_err / np.mean(y_test) * 100
            pred_rel_norm_err = np.abs(np.linalg.norm(p - y_test, axis=1)) / np.abs(np.linalg.norm(y_test, axis=1)) * 100
            pred_rel_scale_err = pred_abs_norm_err / (np.max(y_test[:,0]) - np.min(y_test[:,0])) * 100
            print(f"\nArchitechture: {str(builder.architectures[i][0]).split(' ')[1]}, {builder.architectures[i][1][0]}")
            print(f"% of data: {data_size * 100:.2f}%")
            print(f"Mean Relative Error: {np.mean(pred_rel_norm_err):.3f}%")
            print(f"Max Relative Error: {max(pred_rel_norm_err):.3f}%")
            print(f"Mean Absolute Error: {np.mean(pred_abs_norm_err):.3f} mm")
            print(f"Max Absolute Error: {max(pred_abs_norm_err):.3f} mm")
            print(f"Mean Relative Error (Mean Length): {np.mean(pred_rel_mean_err):.3f} %")
            print(f"Max Relative Error (Mean Length): {max(pred_rel_mean_err):.3f} %")
            print(f"Mean Relative Error (Full-Scale): {np.mean(pred_rel_scale_err):.3f}%")
            print(f"Max Relative Error (Full-Scale): {max(pred_rel_scale_err):.3f}%")

            if write_flag:
                result_file.write(f"\n{str(builder.architectures[i][0]).split(' ')[1]}, {builder.architectures[i][1][0]}; ")
                result_file.write(f"{data_size*100:.2f}; ")
                if builder.early_stopping == None or builder.early_stopping.stopped_epoch == None or builder.early_stopping.stopped_epoch == 0:
                    result_file.write(f"{MAX_EPOCH}; ")
                else: result_file.write(f"{len(builder.histories[i].history['val_loss'])}; ")

                result_file.write(f"{builder.histories[i].history['val_loss'][-1]:3f}; ")
                
                result_file.write(f"{np.mean(pred_rel_norm_err):.3f}; ")
                result_file.write(f"{max(pred_rel_norm_err):.3f}; ")
                result_file.write(f"{np.mean(pred_abs_norm_err):.3f}; ")
                result_file.write(f"{max(pred_abs_norm_err):.3f}; ")
                
                result_file.write(f"{np.std(pred_abs_norm_err):.3f}; ")
                result_file.write(f"{np.mean(y_test):3f}; ")
                result_file.write(f"{np.max(y_test[:,0]) - np.min(y_test[:,0]):3f}")
                
                # result_file.write(f"{np.mean(pred_rel_mean_err):.3f}; ")
                # result_file.write(f"{max(pred_rel_mean_err):.3f}; ")
                # result_file.write(f"{np.mean(pred_rel_scale_err):.3f}; ")
                # result_file.write(f"{max(pred_rel_scale_err):.3f}")
                

            builder.save_models(prefix=f"{str(builder.architectures[0][0]).split()[1]}_{int(data_size*100)}pct_{h}L", folder=models_folder)

            if not os.path.exists(f"{models_folder}/imgs/"): os.makedirs(f"{models_folder}/imgs/")
        
            if write_flag and data_size in [0.25, 0.5, 0.75, 1]: plt.savefig(f"{models_folder}/imgs/{str(builder.architectures[0][0]).split()[1]}_{int(data_size*100)}pct_{h}L.png")
            # if write_flag and data_size in [0.25, 0.5, 1]: plt.savefig(f'./results/final_datasets2/imgs/training_{data_size*100:.0f}_{h}L_{dt}.png')
        
        if write_flag: result_file.flush()

if write_flag: result_file.close()
plt.show()
# Out:
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 1401, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 953, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 1081, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90]
# % of data: 12.50%
# Mean Relative Error: 1.235%
# Max Relative Error: 4.662%
# Mean Absolute Error: 2.492 mm
# Max Absolute Error: 9.761 mm
# Mean Relative Error (Mean Length): 2.168 %
# Max Relative Error (Mean Length): 8.493 %
# Mean Relative Error (Full-Scale): 4.331%
# Max Relative Error (Full-Scale): 16.965%
#
# Architechture: mlp_1, [95, 95]
# % of data: 12.50%
# Mean Relative Error: 1.249%
# Max Relative Error: 6.045%
# Mean Absolute Error: 2.521 mm
# Max Absolute Error: 13.289 mm
# Mean Relative Error (Mean Length): 2.194 %
# Max Relative Error (Mean Length): 11.564 %
# Mean Relative Error (Full-Scale): 4.382%
# Max Relative Error (Full-Scale): 23.098%
#
# Architechture: mlp_1, [100, 100]
# % of data: 12.50%
# Mean Relative Error: 1.242%
# Max Relative Error: 5.508%
# Mean Absolute Error: 2.505 mm
# Max Absolute Error: 12.107 mm
# Mean Relative Error (Mean Length): 2.180 %
# Max Relative Error (Mean Length): 10.535 %
# Mean Relative Error (Full-Scale): 4.355%
# Max Relative Error (Full-Scale): 21.044%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 806, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 880, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 2771, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90, 90]
# % of data: 12.50%
# Mean Relative Error: 1.232%
# Max Relative Error: 5.750%
# Mean Absolute Error: 2.486 mm
# Max Absolute Error: 12.641 mm
# Mean Relative Error (Mean Length): 2.163 %
# Max Relative Error (Mean Length): 11.000 %
# Mean Relative Error (Full-Scale): 4.321%
# Max Relative Error (Full-Scale): 21.971%
#
# Architechture: mlp_1, [95, 95, 95]
# % of data: 12.50%
# Mean Relative Error: 1.072%
# Max Relative Error: 5.097%
# Mean Absolute Error: 2.147 mm
# Max Absolute Error: 11.205 mm
# Mean Relative Error (Mean Length): 1.869 %
# Max Relative Error (Mean Length): 9.750 %
# Mean Relative Error (Full-Scale): 3.732%
# Max Relative Error (Full-Scale): 19.475%
#
# Architechture: mlp_1, [100, 100, 100]
# % of data: 12.50%
# Mean Relative Error: 1.007%
# Max Relative Error: 4.653%
# Mean Absolute Error: 2.008 mm
# Max Absolute Error: 8.080 mm
# Mean Relative Error (Mean Length): 1.747 %
# Max Relative Error (Mean Length): 7.031 %
# Mean Relative Error (Full-Scale): 3.490%
# Max Relative Error (Full-Scale): 14.044%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 700, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 848, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 1119, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90]
# % of data: 25.00%
# Mean Relative Error: 1.151%
# Max Relative Error: 5.080%
# Mean Absolute Error: 2.330 mm
# Max Absolute Error: 11.342 mm
# Mean Relative Error (Mean Length): 2.027 %
# Max Relative Error (Mean Length): 9.870 %
# Mean Relative Error (Full-Scale): 4.050%
# Max Relative Error (Full-Scale): 19.714%
#
# Architechture: mlp_1, [95, 95]
# % of data: 25.00%
# Mean Relative Error: 1.049%
# Max Relative Error: 4.755%
# Mean Absolute Error: 2.104 mm
# Max Absolute Error: 8.256 mm
# Mean Relative Error (Mean Length): 1.831 %
# Max Relative Error (Mean Length): 7.184 %
# Mean Relative Error (Full-Scale): 3.658%
# Max Relative Error (Full-Scale): 14.350%
#
# Architechture: mlp_1, [100, 100]
# % of data: 25.00%
# Mean Relative Error: 1.013%
# Max Relative Error: 4.792%
# Mean Absolute Error: 2.031 mm
# Max Absolute Error: 8.320 mm
# Mean Relative Error (Mean Length): 1.767 %
# Max Relative Error (Mean Length): 7.240 %
# Mean Relative Error (Full-Scale): 3.530%
# Max Relative Error (Full-Scale): 14.462%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 876, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 574, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 999, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90, 90]
# % of data: 25.00%
# Mean Relative Error: 1.034%
# Max Relative Error: 4.901%
# Mean Absolute Error: 2.078 mm
# Max Absolute Error: 8.509 mm
# Mean Relative Error (Mean Length): 1.809 %
# Max Relative Error (Mean Length): 7.404 %
# Mean Relative Error (Full-Scale): 3.613%
# Max Relative Error (Full-Scale): 14.790%
#
# Architechture: mlp_1, [95, 95, 95]
# % of data: 25.00%
# Mean Relative Error: 0.931%
# Max Relative Error: 4.771%
# Mean Absolute Error: 1.864 mm
# Max Absolute Error: 8.285 mm
# Mean Relative Error (Mean Length): 1.622 %
# Max Relative Error (Mean Length): 7.209 %
# Mean Relative Error (Full-Scale): 3.239%
# Max Relative Error (Full-Scale): 14.400%
#
# Architechture: mlp_1, [100, 100, 100]
# % of data: 25.00%
# Mean Relative Error: 0.843%
# Max Relative Error: 5.011%
# Mean Absolute Error: 1.677 mm
# Max Absolute Error: 8.701 mm
# Mean Relative Error (Mean Length): 1.459 %
# Max Relative Error (Mean Length): 7.571 %
# Mean Relative Error (Full-Scale): 2.914%
# Max Relative Error (Full-Scale): 15.123%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 657, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 1220, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 665, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90]
# % of data: 37.50%
# Mean Relative Error: 1.226%
# Max Relative Error: 4.628%
# Mean Absolute Error: 2.478 mm
# Max Absolute Error: 9.952 mm
# Mean Relative Error (Mean Length): 2.156 %
# Max Relative Error (Mean Length): 8.660 %
# Mean Relative Error (Full-Scale): 4.307%
# Max Relative Error (Full-Scale): 17.298%
#
# Architechture: mlp_1, [95, 95]
# % of data: 37.50%
# Mean Relative Error: 0.889%
# Max Relative Error: 4.769%
# Mean Absolute Error: 1.772 mm
# Max Absolute Error: 8.281 mm
# Mean Relative Error (Mean Length): 1.542 %
# Max Relative Error (Mean Length): 7.206 %
# Mean Relative Error (Full-Scale): 3.080%
# Max Relative Error (Full-Scale): 14.394%
#
# Architechture: mlp_1, [100, 100]
# % of data: 37.50%
# Mean Relative Error: 1.031%
# Max Relative Error: 4.764%
# Mean Absolute Error: 2.065 mm
# Max Absolute Error: 8.363 mm
# Mean Relative Error (Mean Length): 1.797 %
# Max Relative Error (Mean Length): 7.277 %
# Mean Relative Error (Full-Scale): 3.590%
# Max Relative Error (Full-Scale): 14.536%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 763, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 564, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 1133, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90, 90]
# % of data: 37.50%
# Mean Relative Error: 0.869%
# Max Relative Error: 5.061%
# Mean Absolute Error: 1.731 mm
# Max Absolute Error: 8.787 mm
# Mean Relative Error (Mean Length): 1.506 %
# Max Relative Error (Mean Length): 7.647 %
# Mean Relative Error (Full-Scale): 3.009%
# Max Relative Error (Full-Scale): 15.274%
#
# Architechture: mlp_1, [95, 95, 95]
# % of data: 37.50%
# Mean Relative Error: 1.150%
# Max Relative Error: 4.855%
# Mean Absolute Error: 2.329 mm
# Max Absolute Error: 10.672 mm
# Mean Relative Error (Mean Length): 2.027 %
# Max Relative Error (Mean Length): 9.286 %
# Mean Relative Error (Full-Scale): 4.048%
# Max Relative Error (Full-Scale): 18.549%
#
# Architechture: mlp_1, [100, 100, 100]
# % of data: 37.50%
# Mean Relative Error: 0.982%
# Max Relative Error: 4.875%
# Mean Absolute Error: 1.972 mm
# Max Absolute Error: 9.187 mm
# Mean Relative Error (Mean Length): 1.716 %
# Max Relative Error (Mean Length): 7.994 %
# Mean Relative Error (Full-Scale): 3.428%
# Max Relative Error (Full-Scale): 15.968%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 724, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 589, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 647, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90]
# % of data: 50.00%
# Mean Relative Error: 1.058%
# Max Relative Error: 4.636%
# Mean Absolute Error: 2.119 mm
# Max Absolute Error: 8.049 mm
# Mean Relative Error (Mean Length): 1.844 %
# Max Relative Error (Mean Length): 7.004 %
# Mean Relative Error (Full-Scale): 3.683%
# Max Relative Error (Full-Scale): 13.991%
#
# Architechture: mlp_1, [95, 95]
# % of data: 50.00%
# Mean Relative Error: 0.898%
# Max Relative Error: 4.790%
# Mean Absolute Error: 1.788 mm
# Max Absolute Error: 8.317 mm
# Mean Relative Error (Mean Length): 1.556 %
# Max Relative Error (Mean Length): 7.237 %
# Mean Relative Error (Full-Scale): 3.108%
# Max Relative Error (Full-Scale): 14.455%
#
# Architechture: mlp_1, [100, 100]
# % of data: 50.00%
# Mean Relative Error: 0.836%
# Max Relative Error: 4.843%
# Mean Absolute Error: 1.666 mm
# Max Absolute Error: 8.410 mm
# Mean Relative Error (Mean Length): 1.450 %
# Max Relative Error (Mean Length): 7.318 %
# Mean Relative Error (Full-Scale): 2.896%
# Max Relative Error (Full-Scale): 14.617%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 546, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 541, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 1012, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90, 90]
# % of data: 50.00%
# Mean Relative Error: 1.079%
# Max Relative Error: 4.909%
# Mean Absolute Error: 2.164 mm
# Max Absolute Error: 8.981 mm
# Mean Relative Error (Mean Length): 1.883 %
# Max Relative Error (Mean Length): 7.815 %
# Mean Relative Error (Full-Scale): 3.761%
# Max Relative Error (Full-Scale): 15.610%
#
# Architechture: mlp_1, [95, 95, 95]
# % of data: 50.00%
# Mean Relative Error: 0.876%
# Max Relative Error: 4.794%
# Mean Absolute Error: 1.745 mm
# Max Absolute Error: 8.324 mm
# Mean Relative Error (Mean Length): 1.518 %
# Max Relative Error (Mean Length): 7.243 %
# Mean Relative Error (Full-Scale): 3.033%
# Max Relative Error (Full-Scale): 14.468%
#
# Architechture: mlp_1, [100, 100, 100]
# % of data: 50.00%
# Mean Relative Error: 1.017%
# Max Relative Error: 4.595%
# Mean Absolute Error: 2.043 mm
# Max Absolute Error: 8.629 mm
# Mean Relative Error (Mean Length): 1.778 %
# Max Relative Error (Mean Length): 7.509 %
# Mean Relative Error (Full-Scale): 3.552%
# Max Relative Error (Full-Scale): 14.998%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 580, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 488, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 509, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90]
# % of data: 62.50%
# Mean Relative Error: 1.150%
# Max Relative Error: 5.150%
# Mean Absolute Error: 2.328 mm
# Max Absolute Error: 11.320 mm
# Mean Relative Error (Mean Length): 2.026 %
# Max Relative Error (Mean Length): 9.851 %
# Mean Relative Error (Full-Scale): 4.046%
# Max Relative Error (Full-Scale): 19.676%
#
# Architechture: mlp_1, [95, 95]
# % of data: 62.50%
# Mean Relative Error: 1.215%
# Max Relative Error: 4.784%
# Mean Absolute Error: 2.456 mm
# Max Absolute Error: 10.516 mm
# Mean Relative Error (Mean Length): 2.137 %
# Max Relative Error (Mean Length): 9.151 %
# Mean Relative Error (Full-Scale): 4.268%
# Max Relative Error (Full-Scale): 18.279%
#
# Architechture: mlp_1, [100, 100]
# % of data: 62.50%
# Mean Relative Error: 1.193%
# Max Relative Error: 4.979%
# Mean Absolute Error: 2.411 mm
# Max Absolute Error: 10.945 mm
# Mean Relative Error (Mean Length): 2.098 %
# Max Relative Error (Mean Length): 9.524 %
# Mean Relative Error (Full-Scale): 4.191%
# Max Relative Error (Full-Scale): 19.025%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 670, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 833, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 526, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90, 90]
# % of data: 62.50%
# Mean Relative Error: 0.868%
# Max Relative Error: 5.102%
# Mean Absolute Error: 1.727 mm
# Max Absolute Error: 8.858 mm
# Mean Relative Error (Mean Length): 1.503 %
# Max Relative Error (Mean Length): 7.708 %
# Mean Relative Error (Full-Scale): 3.002%
# Max Relative Error (Full-Scale): 15.397%
#
# Architechture: mlp_1, [95, 95, 95]
# % of data: 62.50%
# Mean Relative Error: 1.028%
# Max Relative Error: 4.745%
# Mean Absolute Error: 2.062 mm
# Max Absolute Error: 8.405 mm
# Mean Relative Error (Mean Length): 1.794 %
# Max Relative Error (Mean Length): 7.314 %
# Mean Relative Error (Full-Scale): 3.583%
# Max Relative Error (Full-Scale): 14.610%
#
# Architechture: mlp_1, [100, 100, 100]
# % of data: 62.50%
# Mean Relative Error: 0.937%
# Max Relative Error: 5.043%
# Mean Absolute Error: 1.867 mm
# Max Absolute Error: 8.757 mm
# Mean Relative Error (Mean Length): 1.625 %
# Max Relative Error (Mean Length): 7.620 %
# Mean Relative Error (Full-Scale): 3.245%
# Max Relative Error (Full-Scale): 15.220%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 451, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 848, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 464, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90]
# % of data: 75.00%
# Mean Relative Error: 1.202%
# Max Relative Error: 4.795%
# Mean Absolute Error: 2.427 mm
# Max Absolute Error: 10.539 mm
# Mean Relative Error (Mean Length): 2.112 %
# Max Relative Error (Mean Length): 9.171 %
# Mean Relative Error (Full-Scale): 4.219%
# Max Relative Error (Full-Scale): 18.319%
#
# Architechture: mlp_1, [95, 95]
# % of data: 75.00%
# Mean Relative Error: 0.890%
# Max Relative Error: 4.784%
# Mean Absolute Error: 1.772 mm
# Max Absolute Error: 8.307 mm
# Mean Relative Error (Mean Length): 1.542 %
# Max Relative Error (Mean Length): 7.228 %
# Mean Relative Error (Full-Scale): 3.081%
# Max Relative Error (Full-Scale): 14.439%
#
# Architechture: mlp_1, [100, 100]
# % of data: 75.00%
# Mean Relative Error: 1.223%
# Max Relative Error: 4.715%
# Mean Absolute Error: 2.471 mm
# Max Absolute Error: 10.288 mm
# Mean Relative Error (Mean Length): 2.150 %
# Max Relative Error (Mean Length): 8.953 %
# Mean Relative Error (Full-Scale): 4.294%
# Max Relative Error (Full-Scale): 17.883%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 455, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 853, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 571, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90, 90]
# % of data: 75.00%
# Mean Relative Error: 1.157%
# Max Relative Error: 5.227%
# Mean Absolute Error: 2.339 mm
# Max Absolute Error: 11.489 mm
# Mean Relative Error (Mean Length): 2.035 %
# Max Relative Error (Mean Length): 9.997 %
# Mean Relative Error (Full-Scale): 4.065%
# Max Relative Error (Full-Scale): 19.969%
#
# Architechture: mlp_1, [95, 95, 95]
# % of data: 75.00%
# Mean Relative Error: 0.954%
# Max Relative Error: 4.833%
# Mean Absolute Error: 1.913 mm
# Max Absolute Error: 8.806 mm
# Mean Relative Error (Mean Length): 1.665 %
# Max Relative Error (Mean Length): 7.663 %
# Mean Relative Error (Full-Scale): 3.326%
# Max Relative Error (Full-Scale): 15.307%
#
# Architechture: mlp_1, [100, 100, 100]
# % of data: 75.00%
# Mean Relative Error: 0.817%
# Max Relative Error: 4.995%
# Mean Absolute Error: 1.628 mm
# Max Absolute Error: 8.672 mm
# Mean Relative Error (Mean Length): 1.416 %
# Max Relative Error (Mean Length): 7.546 %
# Mean Relative Error (Full-Scale): 2.829%
# Max Relative Error (Full-Scale): 15.073%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 500, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 433, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 490, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90]
# % of data: 87.50%
# Mean Relative Error: 0.990%
# Max Relative Error: 4.750%
# Mean Absolute Error: 1.984 mm
# Max Absolute Error: 8.248 mm
# Mean Relative Error (Mean Length): 1.726 %
# Max Relative Error (Mean Length): 7.177 %
# Mean Relative Error (Full-Scale): 3.448%
# Max Relative Error (Full-Scale): 14.337%
#
# Architechture: mlp_1, [95, 95]
# % of data: 87.50%
# Mean Relative Error: 1.212%
# Max Relative Error: 4.816%
# Mean Absolute Error: 2.448 mm
# Max Absolute Error: 10.586 mm
# Mean Relative Error (Mean Length): 2.130 %
# Max Relative Error (Mean Length): 9.211 %
# Mean Relative Error (Full-Scale): 4.256%
# Max Relative Error (Full-Scale): 18.400%
#
# Architechture: mlp_1, [100, 100]
# % of data: 87.50%
# Mean Relative Error: 0.985%
# Max Relative Error: 4.814%
# Mean Absolute Error: 1.973 mm
# Max Absolute Error: 8.359 mm
# Mean Relative Error (Mean Length): 1.717 %
# Max Relative Error (Mean Length): 7.274 %
# Mean Relative Error (Full-Scale): 3.429%
# Max Relative Error (Full-Scale): 14.529%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 464, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 1020, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 424, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90, 90]
# % of data: 87.50%
# Mean Relative Error: 0.904%
# Max Relative Error: 4.570%
# Mean Absolute Error: 1.799 mm
# Max Absolute Error: 7.935 mm
# Mean Relative Error (Mean Length): 1.565 %
# Max Relative Error (Mean Length): 6.905 %
# Mean Relative Error (Full-Scale): 3.126%
# Max Relative Error (Full-Scale): 13.792%
#
# Architechture: mlp_1, [95, 95, 95]
# % of data: 87.50%
# Mean Relative Error: 0.897%
# Max Relative Error: 5.114%
# Mean Absolute Error: 1.783 mm
# Max Absolute Error: 8.879 mm
# Mean Relative Error (Mean Length): 1.552 %
# Max Relative Error (Mean Length): 7.727 %
# Mean Relative Error (Full-Scale): 3.100%
# Max Relative Error (Full-Scale): 15.434%
#
# Architechture: mlp_1, [100, 100, 100]
# % of data: 87.50%
# Mean Relative Error: 0.864%
# Max Relative Error: 5.005%
# Mean Absolute Error: 1.716 mm
# Max Absolute Error: 8.690 mm
# Mean Relative Error (Mean Length): 1.493 %
# Max Relative Error (Mean Length): 7.562 %
# Mean Relative Error (Full-Scale): 2.983%
# Max Relative Error (Full-Scale): 15.105%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 430, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 464, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 419, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90]
# % of data: 100.00%
# Mean Relative Error: 1.175%
# Max Relative Error: 4.825%
# Mean Absolute Error: 2.372 mm
# Max Absolute Error: 9.531 mm
# Mean Relative Error (Mean Length): 2.064 %
# Max Relative Error (Mean Length): 8.294 %
# Mean Relative Error (Full-Scale): 4.122%
# Max Relative Error (Full-Scale): 16.566%
#
# Architechture: mlp_1, [95, 95]
# % of data: 100.00%
# Mean Relative Error: 1.001%
# Max Relative Error: 4.745%
# Mean Absolute Error: 2.005 mm
# Max Absolute Error: 8.238 mm
# Mean Relative Error (Mean Length): 1.745 %
# Max Relative Error (Mean Length): 7.169 %
# Mean Relative Error (Full-Scale): 3.485%
# Max Relative Error (Full-Scale): 14.319%
#
# Architechture: mlp_1, [100, 100]
# % of data: 100.00%
# Mean Relative Error: 1.206%
# Max Relative Error: 4.727%
# Mean Absolute Error: 2.436 mm
# Max Absolute Error: 10.388 mm
# Mean Relative Error (Mean Length): 2.120 %
# Max Relative Error (Mean Length): 9.040 %
# Mean Relative Error (Full-Scale): 4.234%
# Max Relative Error (Full-Scale): 18.056%
# Training model 1/3
# Moving Average early stopping: Training stopped at epoch 427, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 2/3
# Moving Average early stopping: Training stopped at epoch 385, val_loss moving average didn't improve for 300 consecutive epochs.
# Training model 3/3
# Moving Average early stopping: Training stopped at epoch 444, val_loss moving average didn't improve for 300 consecutive epochs.
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
#
# Architechture: mlp_1, [90, 90, 90]
# % of data: 100.00%
# Mean Relative Error: 0.908%
# Max Relative Error: 4.980%
# Mean Absolute Error: 1.811 mm
# Max Absolute Error: 8.647 mm
# Mean Relative Error (Mean Length): 1.576 %
# Max Relative Error (Mean Length): 7.525 %
# Mean Relative Error (Full-Scale): 3.148%
# Max Relative Error (Full-Scale): 15.030%
#
# Architechture: mlp_1, [95, 95, 95]
# % of data: 100.00%
# Mean Relative Error: 1.042%
# Max Relative Error: 4.652%
# Mean Absolute Error: 2.089 mm
# Max Absolute Error: 8.078 mm
# Mean Relative Error (Mean Length): 1.817 %
# Max Relative Error (Mean Length): 7.029 %
# Mean Relative Error (Full-Scale): 3.630%
# Max Relative Error (Full-Scale): 14.041%
#
# Architechture: mlp_1, [100, 100, 100]
# % of data: 100.00%
# Mean Relative Error: 0.908%
# Max Relative Error: 5.073%
# Mean Absolute Error: 1.809 mm
# Max Absolute Error: 8.807 mm
# Mean Relative Error (Mean Length): 1.574 %
# Max Relative Error (Mean Length): 7.664 %
# Mean Relative Error (Full-Scale): 3.145%
# Max Relative Error (Full-Scale): 15.309%

# %%
# if not os.path.exists(f"{folder}/imgs/"): os.makedirs(f"{folder}/imgs/")

# plt.savefig(f"{folder}/imgs/{str(builder.architectures[0][0]).split()[1]}_{int(data_size*100)}pct_{h}L.png")

# result_file.flush()

# result_file.close()
# import os

# os.fsync(result_file)

# %%
retest_flag = False
# retest_flag = True

if retest_flag:
    from keras.models import load_model
    import os
    # models_folder = "./results/final_datasets3/models_2024-04-13T100152"
    date = models_folder.split('_')[-1]
    print(date)
    # models = [(model_file, load_model(os.path.join(models_folder, model_file))) for model_file in os.listdir(models_folder) ]

    result_filepath = [file for file in os.listdir('/'.join(models_folder.split('/')[:-1])) if date in file and file.endswith(".txt")][0]
    result_filepath = os.path.join('/'.join(models_folder.split('/')[:-1]), result_filepath).replace('\\','/')
    # print(result_filepath)
    with open(result_filepath, 'a') as result_file:
        for model_file in [file for file in os.listdir(models_folder) if file.endswith(".keras")]:
            model = load_model(os.path.join(models_folder, model_file))
            p = model.predict(x_test)
            pred_abs_norm_err = np.abs(np.linalg.norm(p - y_test, axis=1))
            pred_rel_mean_err = pred_abs_norm_err / np.mean(y_test) * 100
            pred_rel_norm_err = np.abs(np.linalg.norm(p - y_test, axis=1)) / np.abs(np.linalg.norm(y_test, axis=1)) * 100
            pred_rel_scale_err = pred_abs_norm_err / (np.max(y_test[:,0]) - np.min(y_test[:,0])) * 100

            model_props = model_file.split('.', 1)[0].split('_')
            # print(model_props)
            # print(f"\nmlp_1, {[int(model_props[-1])] * int(model_props[-2][:-1])}; ")
            # pct = ''.join([char for char in model_props[-3] if char.isdigit()])
            # print(float('0.' + model_props[-3][:-3]))
            # print(f"{min(data_size_range, key=lambda x: abs(x - float('0.' + model_props[-3][:-3])))*100:.2f}; ")
            # print(f"{np.nan}; ")
            # print(f"{np.nan}")
            if model_file.startswith("mlp_1"):
                result_file.write(f"\nmlp_1, {[int(model_props[-1])] * int(model_props[-2][:-1])}; ")
            elif model_file.startswith("rnn"):
                result_file.write(f"\nrnn, {[int(model_props[-1])] * int(model_props[-2][:-1])}; ")

            result_file.write(f"{min(data_size_range, key=lambda x: abs(x - float('0.' + model_props[-3][:-3])))*100:.2f}; ")
            result_file.write(f"{np.nan}; ")
            # result_file.write(f"{data_size*100:.2f}; ")
            # if builder.early_stopping == None or builder.early_stopping.stopped_epoch == None or builder.early_stopping.stopped_epoch == 0:
            #     result_file.write(f"{MAX_EPOCH}; ")
            # else: result_file.write(f"{len(builder.histories[i].history['val_loss'])}; ")

            result_file.write(f"{np.nan}; ")
            # result_file.write(f"{builder.histories[i].history['val_loss'][-1]:3f}; ")
            
            result_file.write(f"{np.mean(pred_rel_norm_err):.3f}; ")
            result_file.write(f"{max(pred_rel_norm_err):.3f}; ")
            result_file.write(f"{np.mean(pred_abs_norm_err):.3f}; ")
            result_file.write(f"{max(pred_abs_norm_err):.3f}; ")
            
            result_file.write(f"{np.std(pred_abs_norm_err):.3f}; ")
            result_file.write(f"{np.mean(y_test):3f}; ")
            result_file.write(f"{np.max(y_test[:,0]) - np.min(y_test[:,0]):3f}")
